# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# Selenium WebDriver 설정 (ChromeDriver 경로를 생략)
driver = webdriver.Chrome()

# URL 열기
url = "https://www.bigkinds.or.kr/v2/news/recentNews.do"
driver.get(url)

# 페이지 로드 대기
time.sleep(5)  # 페이지가 로드될 시간을 충분히 대기 (필요 시 조정)

# 스크롤 다운으로 동적 콘텐츠 로드
body = driver.find_element(By.TAG_NAME, "body")


# 데이터 크롤링
articles = driver.find_elements(By.CSS_SELECTOR, "div.cont.news-detail")
for article in articles:
    try:
        title = article.find_element(By.CSS_SELECTOR, "strong.title").text
        summary = article.find_element(By.CSS_SELECTOR, "p.text").text
        link = article.find_element(By.CSS_SELECTOR, "div.info a").get_attribute("href")
    except Exception as e:
        title, summary, link = "N/A", "N/A", "N/A"

    print(f"제목: {title}")
    print(f"요약: {summary}")
    print(f"원문 링크: {link}")
    print("-" * 50)

# 드라이버 종료
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# Selenium WebDriver 설정 (ChromeDriver 경로를 생략)
driver = webdriver.Chrome()

# URL 열기
url = "https://www.bigkinds.or.kr/v2/news/recentNews.do"
driver.get(url)

# 페이지 로드 대기
time.sleep(5)  # 페이지가 로드될 시간을 충분히 대기 (필요 시 조정)

# 스크롤 다운으로 동적 콘텐츠 로드
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(5)  # 추가 대기

# 데이터 크롤링
articles = driver.find_elements(By.CSS_SELECTOR, "div.cont.news-detail")
for article in articles:
    try:
        title = article.find_element(By.CSS_SELECTOR, "strong.title").text
        summary = article.find_element(By.CSS_SELECTOR, "p.text").text
        link = article.find_element(By.CSS_SELECTOR, "a").get_attribute("href")
    except Exception as e:
        title, summary, link = "N/A", "N/A", "N/A"

    print(f"제목: {title}")
    print(f"본문: {summary}")
    print(f"원문 링크: {link}")
    print("-" * 50)

# 드라이버 종료
driver.quit()
# Out:
# 제목: 비수도권 상공회의소협의회 출범
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 박서진 “정신질환으로 군 면제, 활동차질 우려해 밝히기 어려웠다”
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: [라인W 날씨] 밤사이 찬바람 불며 추워져…내일 아침 서울 -4도
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 이 시각 소방청 상황실
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 美, HBM 포함 대중 반도체 수출규제 강화…삼성·하이닉스 영향
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 경기도의회 국민의힘, 2025년 예산안 '불요불급 예산 전액 삭감' 선언
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 3일 아침 최저 영하 8도…밤부턴 곳곳에 눈·비
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: [속보] 中상무부, 미국의 對中 반도체 수출 통제에 "단호히 반대"
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: "콘돔보다 강력하다"…'죽음의 병' 에이즈 백신 드디어 나왔다는데 관건은?
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 美, 對中 반도체 수출통제 발표…한국산 HBM도 적용
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: [속보] 中상무부, 미국의 對中 반도체 수출 통제에 "단호히 반대"
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 내년 여름부터 ‘AI 예보’…40초 만에 강수 예측
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
