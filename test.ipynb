# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# Selenium WebDriver 설정 (ChromeDriver 경로를 생략)
driver = webdriver.Chrome()

# URL 열기
url = "https://www.bigkinds.or.kr/v2/news/recentNews.do"
driver.get(url)

# 페이지 로드 대기
time.sleep(5)  # 페이지가 로드될 시간을 충분히 대기 (필요 시 조정)

# 스크롤 다운으로 동적 콘텐츠 로드
body = driver.find_element(By.TAG_NAME, "body")


# 데이터 크롤링
articles = driver.find_elements(By.CSS_SELECTOR, "div.cont.news-detail")
for article in articles:
    try:
        title = article.find_element(By.CSS_SELECTOR, "strong.title").text
        summary = article.find_element(By.CSS_SELECTOR, "p.text").text
        link = article.find_element(By.CSS_SELECTOR, "div.info a").get_attribute("href")
    except Exception as e:
        title, summary, link = "N/A", "N/A", "N/A"

    print(f"제목: {title}")
    print(f"요약: {summary}")
    print(f"원문 링크: {link}")
    print("-" * 50)

# 드라이버 종료
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# Selenium WebDriver 설정 (ChromeDriver 경로를 생략)
driver = webdriver.Chrome()

# URL 열기
url = "https://www.bigkinds.or.kr/v2/news/recentNews.do"
driver.get(url)

# 페이지 로드 대기
time.sleep(5)  # 페이지가 로드될 시간을 충분히 대기 (필요 시 조정)

# 스크롤 다운으로 동적 콘텐츠 로드
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(5)  # 추가 대기

# 데이터 크롤링
articles = driver.find_elements(By.CSS_SELECTOR, "div.cont.news-detail")
for article in articles:
    try:
        title = article.find_element(By.CSS_SELECTOR, "strong.title").text
        summary = article.find_element(By.CSS_SELECTOR, "p.text").text
        link = article.find_element(By.CSS_SELECTOR, "a").get_attribute("href")
    except Exception as e:
        title, summary, link = "N/A", "N/A", "N/A"

    print(f"제목: {title}")
    print(f"본문: {summary}")
    print(f"원문 링크: {link}")
    print("-" * 50)

# 드라이버 종료
driver.quit()
# Out:
# 제목: 강하늘, 미소 머금고 브이
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 경찰, 이상민 전 장관 여인형 방첩사령관 소환 통보
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 대전사회서비스원, 사회서비스 컨퍼런스 개최 우수사례 시상
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: “우리가 산다고?”…덜덜 떠는 효성티앤씨 주주들 [재계 TALK TALK]
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 글로벌 기관투자자 줄줄이 ‘반대’…두산 사업 재편 흔들 [재계 TALK TALK]
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 농기계 기업 TYM 차남 김식 마약 집행유예 중 ‘약물 운전’ [재계 TALK TALK]
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 화해했다더니…KDDX 2차전 불붙은 HD현대 vs 한화 [재계 TALK TALK]
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 국민청원 등장…현대차증권 유상증자에 뿔난 주주 [재계 TALK TALK]
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 스무살에 눈물 머금고 판 운동화가 만들어낸 기적 [내 인생의 오브제]
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: “부지런히 벌어봤자 집값 못 따라간다”…더 깊어진 자산 양극화 골짜기
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 김장철 원산지 위반 19건
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------
# 제목: 강원FC, 정경호 감독 선임 후 내년 시즌 기대감 증폭
# 본문:
# 원문 링크: https://www.bigkinds.or.kr/v2/news/recentNews.do#modal-news1
# --------------------------------------------------

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# Selenium WebDriver 설정 (ChromeDriver 경로를 생략)
driver = webdriver.Chrome()

# URL 열기
url = "https://www.bigkinds.or.kr/v2/news/recentNews.do"
driver.get(url)

# 페이지 로드 대기
time.sleep(5)  # 페이지가 로드될 시간을 충분히 대기 (필요 시 조정)

# 스크롤 다운으로 동적 콘텐츠 로드
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(5)  # 추가 대기

texts = []
# 데이터 크롤링
articles = driver.find_elements(By.CSS_SELECTOR, "div.cont.news-detail")
for article in articles:
    try:
        title = article.find_element(By.CSS_SELECTOR, "strong.title").text
        summary = article.find_element(By.CSS_SELECTOR, "p.text").text
        link = article.find_element(By.CSS_SELECTOR, "div.info").find_element(By.CSS_SELECTOR, "a").get_attribute("href")
    except Exception as e:
        title, summary, link = "N/A", "N/A", "N/A"

    texts.append(summary)
    print(f"제목: {title}")
    print(f"본문: {summary}")
    print(f"원문 링크: {link}")
    print("-" * 50)

# 드라이버 종료
driver.quit()
# Out:
# 제목: 홍준표 “민주당 탄핵 투표 강요는 위헌…투표 포기의 자유도 있어”
# 본문:
# 원문 링크: http://www.segye.com/content/html/2024/12/09/20241209517878.html
# --------------------------------------------------
# 제목: 교회서 숨진 멍투성이 여고생…신도들, 살인죄 '무죄' 이유
# 본문:
# 원문 링크: http://news.moneytoday.co.kr/view/mtview.php?no=2024120920204655919&type=2
# --------------------------------------------------
# 제목: 사상 첫 ‘대통령 출국금지’…이시각 검찰
# 본문:
# 원문 링크: https://news.kbs.co.kr/news/view.do?ncd=8126379&amp;ref=DA
# --------------------------------------------------
# 제목: 일본인 3명 중 2명, 한국 비상계엄에 “한일관계 영향 우려”
# 본문:
# 원문 링크: http://www.segye.com/content/html/2024/12/09/20241209517912.html
# --------------------------------------------------
# 제목: ‘내란’으로…주택 ‘대란’…3년 뒤 공급부족 불 보듯
# 본문:
# 원문 링크: https://www.khan.co.kr/article/202412092107015
# --------------------------------------------------
# 제목: 계엄 사태 반영 않고도…KDI “내수·투자 암울”
# 본문:
# 원문 링크: https://www.khan.co.kr/article/202412092107005
# --------------------------------------------------
# 제목: 국가신뢰도 하락, 잘나가던 ‘K방산’ 발목잡았다
# 본문:
# 원문 링크: https://www.khan.co.kr/article/202412092107025
# --------------------------------------------------
# 제목: 아시아나, 제주 마일리지 좌석 추가 공급
# 본문:
# 원문 링크: https://www.khan.co.kr/article/202412092106005
# --------------------------------------------------
# 제목: 의사들 ‘처단’ 포고령에 반발, 실손보험 등 개선 논의 거부…의료개혁도 ‘차질’
# 본문:
# 원문 링크: https://www.khan.co.kr/article/202412092106015
# --------------------------------------------------
# 제목: 임시완, 달콤한 하트
# 본문:
# 원문 링크: https://sports.hankooki.com/news/articleView.html?idxno=6883440
# --------------------------------------------------
# 제목: 7백억 '수원 일가족 전세사기' 주범, 1심 징역 15년
# 본문:
# 원문 링크: https://www.ytn.co.kr/_ln/0103_202412092105526135
# --------------------------------------------------
# 제목: "국민의힘 해체하라"…항의 방문에 폐문
# 본문:
# 원문 링크: https://news.sbs.co.kr/news/endPage.do?news_id=N1007905446&plink=ORI&cooper=ETC
# --------------------------------------------------

# %%
t_split = []
for a in texts:
    t_split.append(a.split('.'))
