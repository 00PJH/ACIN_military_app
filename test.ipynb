# %%
import pandas as pd
from datetime import date
from classification_title import load_csv_tokenizer, tokenize_encode, perform_inference, run

# 0. create file name
def create_bk_news_data_name():
    # 파일 이름 지정
    today = date.today()
    str_today = str(today.year) + str(today.month)  + str(today.day)
    input_file_path = ("NewsResult" + "_" + str_today + "-" + str_today  + ".xlsx")

    return input_file_path

# 1. extract only title
def extract_title(file_path):
    # excel 파일 읽기
    df = pd.read_excel(file_path)
    # 제목 열만 추출
    # df_titles_only = df[['제목']]
    # df_titles_only = df_titles_only.rename(columns={'제목':'title'})
    df_titles_URL = df[['제목','URL']]
    df_titles_URL = df_titles_URL.rename(columns={'제목':'title'}).head(1000)

    return df_titles_URL

# 2. classification titles
def classificatin_titles(input_df):
    prediction_titles = run(input_df)

    return prediction_titles

# 3. run module
def result_data(input_data_path):
    result = classificatin_titles(extract_title(input_data_path))

    # 1부터 시작하여 총 개수까지 index 재배열
    result.index = range(1, len(result) + 1)
    
    # return dataFrame object -> title, prediction
    return result


data = result_data(create_bk_news_data_name())
# Out:
# /home/pjh/.local/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
data
# Out:
#                                                 title  \
# 1                             “한 베 합작투자로 글로벌 강소기업 육성”
# 2                                글로벌 선도형 위성기술 개발 `맞손'
# 3                                      달라진 의회 역할 기대한다
# 4                                    시스템반도체산업 육성 `탄력'
# 5                                             중도 및 중용
# 6                                    극동대 해외 항공업계 첫 진출
# 7                                        정상 경험에 초대합니다
# 8                                    예산군 피너클어워드 '2관왕'
# 9                          공군–롯데지주 '장병 독서활성화' 업무협약 체결
# 10                          러시아, 더 강력한 북한산 화력자산 요구할 듯
# 11                          경남 육군 훈련병, 뜀걸음 중 의식 잃고 사망
# 12                20대 육군 훈련병, 입소 3일 만에 뜀걸음 중 의식 잃고 숨져
# 13                       입소 3일된 육군 훈련병 뜀걸음 중 의식 잃고 숨져
# 14                     HD현대重, 올해 임단협 교섭 타결 "실적 개선 박차"
# 15                       입소 3일차 육군 훈련병 뜀걸음 중 의식 잃고 숨져
# 16                                수소 기반시설 확대 산업화 전략은?
# 17                      입대 3일 만에 육군 훈련병 구보하다 의식 잃고 숨져
# 18                      KBS 인공지능 솔루션 ‘버티고’, 과기정통부 장관상
# 19                   육군 훈련병, 입소 3일만에 아침 구보 중 의식 잃고 사망
# 20                       그물 제거 없이 선체 진입 검토 금성호 수사도 본격
# 21                           일본, 개도국 환경 지키는 일본 초소형 위성
# 22                    육군 훈련병, 입소 3일 만에 뜀걸음하다 의식 잃고 숨져
# 23                          러시아 "영국 스톰섀도 순항미사일 2기 격추"
# 24                       육군 훈련소서 20대 훈련병, 구보 중 쓰러져 숨져
# 25                             “억대 장비 관리 부실 감사도 솜방망이”
# 26                          바다의 ‘AI 선장’ 완전 자율선박 실증 시작
# 27                  육군 훈련병, 아침 뜀걸음 도중 의식 잃고 숨져 입소 사흘째
# 28                          100% 세종산이라더니 알고 보니 ‘그리스산’
# 29                    한일, 日방위상 연내 방한 합의 2015년 이후 9년 만
# 30                          20대 초반 육군 훈련병 구보중 쓰러진뒤 사망
# 31  우크라이나 스톰섀도 쏘자, 러시아 ICBM 날렸다... 확전 속 '트럼프 휴전안'도 부상
# 32                      입소 3일 된 육군 훈련병 뜀걸음하다 의식 잃고 숨져
# 33                            나랏일에 책임을 진다는 것 [박찬승 칼럼]
# 34             김선호 국방 차관 "아세안과 협력 발전...러북 불법 군사협력 규탄"
# 35                 머스크, X에 남긴 의미심장 일본어 ‘와비사비’ 무슨 뜻이길래
